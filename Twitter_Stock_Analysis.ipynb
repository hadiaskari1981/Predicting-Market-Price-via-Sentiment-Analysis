# %%
import pandas as pd
import datetime
import numpy as np
import tweepy
import json
from tweepy import Cursor
import nltk
from nltk.tokenize import sent_tokenize
from nltk import word_tokenize
import re
import string
from nltk.tokenize import TweetTokenizer
from sklearn.model_selection import train_test_split
from nltk.corpus import stopwords
from nltk import SnowballStemmer
from nltk.stem.snowball import SnowballStemmer
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet as wn
from nltk.util import ngrams
from collections import Counter
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import MultinomialNB
from bs4 import BeautifulSoup
import random
import seaborn as sns
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from __future__ import print_function
from wordcloud import WordCloud, STOPWORDS
stop = set(stopwords.words('english'))
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
cols = ['sentiment','id','date','query_string','user','text']
df = pd.read_csv('./training_manutd.csv', header= None, names= cols, encoding = "ISO-8859-1")
#df.to_json('./training_manutd.jsonl')

# %%
df['sentiment'] = df['sentiment'].map({0: 0, 4: 1})
df.sentiment.value_counts()
# 1 Posative 0 Negative
# Out:
# 1    800000
# 0    800000
# Name: sentiment, dtype: int64

# %%
df.text = df.text.str.replace(r'\d+', '')
df.text = df['text'].str.replace('[{}]'.format(string.punctuation), '')
df['text'] = df['text'].apply(lambda x: ' '.join([word for word in x.lower().split() if word not in (stop)]))

# %%
def show_wordcloud(data, title = None):
    wordcloud = WordCloud(
        background_color='black',
        stopwords=stop,
        max_words=300,
        max_font_size=40, 
        collocations = False,
        scale=15,
        random_state=42 # chosen at random by flipping a coin; it was heads
    ).generate(str(data))

    fig = plt.figure(1, figsize=(25, 25))
    plt.axis('off')
    if title: 
        fig.suptitle(title, fontsize=20)
        fig.subplots_adjust(top=2.3)

    plt.imshow(wordcloud)
    plt.show()

show_wordcloud(df['text'])

# %%
word_dist = nltk.FreqDist(df['text'])
word_dist.plot(30)

# %%
pd.set_option('display.max_colwidth', -1)
df.head(2)
# Out:
#    sentiment          id                          date query_string  \
# 0  0          1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY
# 1  0          1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY
#
#               user  \
# 0  _TheSpecialOne_
# 1  scotthamilton
#
#                                                                               text
# 0  switchfoot httptwitpiccomyzl awww thats bummer shoulda got david carr third day
# 1  upset cant update facebook texting might cry result school today also blah

# %%
df.drop(['id', 'date', 'query_string', 'user'], axis = 1, inplace= True)
label = pd.factorize(df['sentiment'].values)[0]

# %%
X_train, X_test, y_train, y_test = train_test_split(df['text'],label, train_size=.8,test_size=.2)

# %%
vec = CountVectorizer()
X_train = vec.fit_transform(X_train)
tfidf_transformer = TfidfTransformer()
x_train_tfidf = tfidf_transformer.fit_transform(X_train)

# %%
cls = MultinomialNB()
cls.fit(x_train_tfidf , y_train)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
X_test = vec.transform(X_test)
x_test_tfidf = tfidf_transformer.transform(X_test)

# %%
print(cls.predict(x_test_tfidf))
x_test_pred = cls.predict(x_test_tfidf)
x = x_test_pred.reshape(1, -1)
y = y_test.reshape(1, -1)
print(y.size)
# Out:
# [0 0 1 ... 0 0 1]
# 320000

# %%
cls.score(x_test_tfidf,y_test)
# Out:
# 0.765671875

# %%
import tweepy
import csv
import pandas as pd
####input your credentials here
consumer_key = ''
consumer_secret = ''
access_token = ''
access_token_secret = ''

consumer_key = 'RR6miKQ2GKE4cSKj889737iMr'
consumer_secret = 'FLLMME41CmVgCRGrydyoBFR3cmJWTpAmkndyjJI29NvkdYXlrE'
access_token = '2520042060-gTmuDa7yaKLWcJhJLq5igkwckTFBdqCBT9OopIh'
access_token_secret = 'tm6UVzoCPPO7L9Hiq9blymj0pVb5v0YMVEZdl2DLnaVLp'

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth,wait_on_rate_limit=True)
#####United Airlines
# Open/Create a file to append data
csvFile = open('TweetsAfter_27_03_2018.csv', 'a', encoding="utf-8")
#Use csv Writer
csvWriter = csv.writer(csvFile)

for tweet in tweepy.Cursor(api.search,q="#ManUtd",count=5000,
                           lang="en",since="2017-04-03").items():
    csvWriter.writerow([tweet.created_at, tweet.text.encode('utf-8'),tweet.retweets])

# %%
df_manutd = pd.read_csv('./Tweets.csv', header = None, names = ['date_time', 'text'],encoding="ISO-8859-1", sep=',')

# %%
df_manutd.head(1)
# Out:
#                                                                                                                                                                       date_time  \
# 2019-02-07 08:48:16  b'RT @Evra: When you are a true @ManUtd fan or player you know what time it is ... never forget. #BusbyBabes #FlowersOfManchester #ManUtd #hi\xe2\x80\xa6'
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# 2019-02-07 08:48:16  <bound method Status.retweets of Status(created_at=datetime.datetime(2019, 2, 7, 8, 48, 16), in_reply_to_user_id=None, _api=<tweepy.api.API object at 0x0000020206AF2CC0>, retweeted_status=Status(created_at=datetime.datetime(2019, 2, 6, 10, 34, 26), in_reply_to_user_id=None, _api=<tweepy.api.API object at 0x0000020206AF2CC0>, _json={'created_at': 'Wed Feb 06 10:34:26 +0000 2019', 'in_reply_to_user_id': None, 'favorited': False, 'metadata': {'result_type': 'recent', 'iso_language_code': 'en'}, 'lang': 'en', 'in_reply_to_screen_name': None, 'retweet_count': 5633, 'coordinates': None, 'favorite_count': 44107, 'geo': None, 'truncated': True, 'in_reply_to_status_id': None, 'in_reply_to_user_id_str': None, 'contributors': None, 'is_quote_status': False, 'possibly_sensitive': False, 'id': 1093095566542819328, 'retweeted': False, 'id_str': '1093095566542819328', 'entities': {'user_mentions': [{'screen_name': 'ManUtd', 'id_str': '558797310', 'indices': [20, 27], 'id': 558797310, 'name': 'Manchester United'}], 'hashtags': [{'text': 'BusbyBabes', 'indices': [85, 96]}], 'urls': [{'url': 'https://t.co/p87yTlHVlS', 'indices': [98, 121], 'expanded_url': 'https://twitter.com/i/web/status/1093095566542819328', 'display_url': 'twitter.com/i/web/status/1
# '}], 'symbols': []}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'text': 'When you are a true @ManUtd fan or player you know what time it is ... never forget. #BusbyBabes
#  https://t.co/p87yTlHVlS', 'place': None, 'in_reply_to_status_id_str': None, 'user': {'created_at': 'Sun Jul 29 11:47:15 +0000 2012', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/968882073544151040/PpFrScjo_normal.jpg', 'is_translation_enabled': False, 'friends_count': 17, 'is_translator': False, 'protected': False, 'description': 'I love this game.', 'profile_sidebar_fill_color': 'DDEEF6', 'following': False, 'lang': 'en', 'profile_link_color': '1B95E0', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_use_background_image': True, 'follow_request_sent': False, 'verified': True, 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/723866725/1519837502', 'time_zone': None, 'name': 'Patrice Evra', 'profile_text_color': '333333', 'contributors_enabled': False, 'geo_enabled': False, 'statuses_count': 91, 'default_profile': False, 'utc_offset': None, 'translator_type': 'none', 'location': 'London, England', 'notifications': False, 'has_extended_profile': False, 'id': 723866725, 'default_profile_image': False, 'favourites_count': 15, 'profile_image_url': 'http://pbs.twimg.com/profile_images/968882073544151040/PpFrScjo_normal.jpg', 'id_str': '723866725', 'entities': {'description': {'urls': []}, 'url': {'urls': [{'url': 'https://t.co/Prxj7Huh09', 'indices': [0, 23], 'expanded_url': 'http://www.yesilovethisgame.com', 'display_url': 'yesilovethisgame.com'}]}}, 'profile_background_color': 'C0DEED', 'screen_name': 'Evra', 'listed_count': 656, 'profile_background_tile': False, 'followers_count': 264944, 'url': 'https://t.co/Prxj7Huh09', 'profile_sidebar_border_color': 'C0DEED'}}, metadata={'result_type': 'recent', 'iso_language_code': 'en'}, lang='en', in_reply_to_screen_name=None, retweet_count=5633, coordinates=None, id_str='1093095566542819328', geo=None, truncated=True, favorited=False, in_reply_to_status_id=None, in_reply_to_user_id_str=None, retweeted=False, is_quote_status=False, possibly_sensitive=False, id=1093095566542819328, contributors=None, favorite_count=44107, entities={'user_mentions': [{'screen_name': 'ManUtd', 'id_str': '558797310', 'indices': [20, 27], 'id': 558797310, 'name': 'Manchester United'}], 'hashtags': [{'text': 'BusbyBabes', 'indices': [85, 96]}], 'urls': [{'url': 'https://t.co/p87yTlHVlS', 'indices': [98, 121], 'expanded_url': 'https://twitter.com/i/web/status/1093095566542819328', 'display_url': 'twitter.com/i/web/status/1
# '}], 'symbols': []}, source='Twitter for iPhone', text='When you are a true @ManUtd fan or player you know what time it is ... never forget. #BusbyBabes
#  https://t.co/p87yTlHVlS', place=None, source_url='http://twitter.com/download/iphone', in_reply_to_status_id_str=None, user=User(profile_background_image_url_https='https://abs.twimg.com/images/themes/theme1/bg.png', is_translator=False, _json={'created_at': 'Sun Jul 29 11:47:15 +0000 2012', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/968882073544151040/PpFrScjo_normal.jpg', 'is_translation_enabled': False, 'friends_count': 17, 'is_translator': False, 'protected': False, 'description': 'I love this game.', 'profile_sidebar_fill_color': 'DDEEF6', 'following': False, 'lang': 'en', 'profile_link_color': '1B95E0', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_use_background_image': True, 'follow_request_sent': False, 'verified': True, 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/723866725/1519837502', 'time_zone': None, 'name': 'Patrice Evra', 'profile_text_color': '333333', 'contributors_enabled': False, 'geo_enabled': False, 'statuses_count': 91, 'default_profile': False, 'utc_offset': None, 'translator_type': 'none', 'location': 'London, England', 'notifications': False, 'has_extended_profile': False, 'id': 723866725, 'default_profile_image': False, 'favourites_count': 15, 'profile_image_url': 'http://pbs.twimg.com/profile_images/968882073544151040/PpFrScjo_normal.jpg', 'id_str': '723866725', 'entities': {'description': {'urls': []}, 'url': {'urls': [{'url': 'https://t.co/Prxj7Huh09', 'indices': [0, 23], 'expanded_url': 'http://www.yesilovethisgame.com', 'display_url': 'yesilovethisgame.com'}]}}, 'profile_background_color': 'C0DEED', 'screen_name': 'Evra', 'listed_count': 656, 'profile_background_tile': False, 'followers_count': 264944, 'url': 'https://t.co/Prxj7Huh09', 'profile_sidebar_border_color': 'C0DEED'}, lang='en', profile_background_image_url='http://abs.twimg.com/images/themes/theme1/bg.png', verified=True, profile_banner_url='https://pbs.twimg.com/profile_banners/723866725/1519837502', profile_use_background_image=True, profile_text_color='333333', default_profile_image=False, geo_enabled=False, statuses_count=91, default_profile=False, utc_offset=None, url='https://t.co/Prxj7Huh09', protected=False, profile_image_url='http://pbs.twimg.com/profile_images/968882073544151040/PpFrScjo_normal.jpg', profile_background_color='C0DEED', screen_name='Evra', listed_count=656, profile_sidebar_border_color='C0DEED', created_at=datetime.datetime(2012, 7, 29, 11, 47, 15), profile_background_tile=False, _api=<tweepy.api.API object at 0x0000020206AF2CC0>, profile_image_url_https='https://pbs.twimg.com/profile_images/968882073544151040/PpFrScjo_normal.jpg', is_translation_enabled=False, friends_count=17, description='I love this game.', following=False, profile_link_color='1B95E0', profile_sidebar_fill_color='DDEEF6', follow_request_sent=False, id_str='723866725', has_extended_profile=False, time_zone=None, name='Patrice Evra', contributors_enabled=False, notifications=False, location='London, England', id=723866725, favourites_count=15, entities={'description': {'urls': []}, 'url': {'urls': [{'url': 'https://t.co/Prxj7Huh09', 'indices': [0, 23], 'expanded_url': 'http://www.yesilovethisgame.com', 'display_url': 'yesilovethisgame.com'}]}}, translator_type='none', followers_count=264944), author=User(profile_background_image_url_https='https://abs.twimg.com/images/themes/theme1/bg.png', is_translator=False, _json={'created_at': 'Sun Jul 29 11:47:15 +0000 2012', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/968882073544151040/PpFrScjo_normal.jpg', 'is_translation_enabled': False, 'friends_count': 17, 'is_translator': False, 'protected': False, 'description': 'I love this game.', 'profile_sidebar_fill_color': 'DDEEF6', 'following': False, 'lang': 'en', 'pro ...
# ', 'place': None, 'in_reply_to_status_id_str': None, 'user': {'created_at': 'Thu Jan 14 13:30:38 +0000 2010', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/962432524063510531/hrblAgrr_normal.jpg', 'is_translation_enabled': False, 'friends_count': 148, 'is_translator': False, 'protected': False, 'description': 'loans officer, mufc, love cooking', 'profile_sidebar_fill_color': 'EFEFEF', 'following': False, 'lang': 'en', 'profile_link_color': '009999', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif', 'profile_use_background_image': True, 'follow_request_sent': False, 'verified': False, 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/104810339/1518296768', 'time_zone': None, 'name': 'Karl Breeze', 'profile_text_color': '333333', 'contributors_enabled': False, 'geo_enabled': True, 'statuses_count': 192, 'default_profile': False, 'utc_offset': None, 'translator_type': 'none', 'location': 'bolton', 'notifications': False, 'has_extended_profile': True, 'id': 104810339, 'default_profile_image': False, 'favourites_count': 48, 'profile_image_url': 'http://pbs.twimg.com/profile_images/962432524063510531/hrblAgrr_normal.jpg', 'id_str': '104810339', 'entities': {'description': {'urls': []}}, 'profile_background_color': '131516', 'screen_name': 'Br3ezy87', 'listed_count': 0, 'profile_background_tile': True, 'followers_count': 59, 'url': None, 'profile_sidebar_border_color': 'EEEEEE'}, 'retweeted_status': {'created_at': 'Wed Feb 06 10:34:26 +0000 2019', 'in_reply_to_user_id': None, 'favorited': False, 'metadata': {'result_type': 'recent', 'iso_language_code': 'en'}, 'lang': 'en', 'in_reply_to_screen_name': None, 'retweet_count': 5633, 'coordinates': None, 'favorite_count': 44107, 'geo': None, 'truncated': True, 'in_reply_to_status_id': None, 'in_reply_to_user_id_str': None, 'contributors': None, 'is_quote_status': False, 'possibly_sensitive': False, 'id': 1093095566542819328, 'retweeted': False, 'id_str': '1093095566542819328', 'entities': {'user_mentions': [{'screen_name': 'ManUtd', 'id_str': '558797310', 'indices': [20, 27], 'id': 558797310, 'name': 'Manchester United'}], 'hashtags': [{'text': 'BusbyBabes', 'indices': [85, 96]}], 'urls': [{'url': 'https://t.co/p87yTlHVlS', 'indices': [98, 121], 'expanded_url': 'https://twitter.com/i/web/status/1093095566542819328', 'display_url': 'twitter.com/i/web/status/1
# '}], 'symbols': []}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'text': 'When you are a true @ManUtd fan or player you know what time it is ... never forget. #BusbyBabes
#  https://t.co/p87yTlHVlS', 'place': None, 'in_reply_to_status_id_str': None, 'user': {'created_at': 'Sun Jul 29 11:47:15 +0000 2012', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/968882073544151040/PpFrScjo_normal.jpg', 'is_translation_enabled': False, 'friends_count': 17, 'is_translator': False, 'protected': False, 'description': 'I love this game.', 'profile_sidebar_fill_color': 'DDEEF6', 'following': False, 'lang': 'en', 'profile_link_color': '1B95E0', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_use_background_image': True, 'follow_request_sent': False, 'verified': True, 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/723866725/1519837502', 'time_zone': None, 'name': 'Patrice Evra', 'profile_text_color': '333333', 'contributors_enabled': False, 'geo_enabled': False, 'statuses_count': 91, 'default_profile': False, 'utc_offset': None, 'translator_type': 'none', 'location': 'London, England', 'notifications': False, 'has_extended_profile': False, 'id': 723866725, 'default_profile_image': False, 'favourites_count': 15, 'profile_image_url': 'http://pbs.twimg.com/profile_images/968882073544151040/PpFrScjo_normal.jpg', 'id_str': '723866725', 'entities': {'description': {'urls': []}, 'url': {'urls': [{'url': 'https://t.co/Prxj7Huh09', 'indices': [0, 23], 'expanded_url': 'http://www.yesilovethisgame.com', 'display_url': 'yesilovethisgame.com'}]}}, 'profile_background_color': 'C0DEED', 'screen_name': 'Evra', 'listed_count': 656, 'profile_background_tile': False, 'followers_count': 264944, 'url': 'https://t.co/Prxj7Huh09', 'profile_sidebar_border_color': 'C0DEED'}}}, metadata={'result_type': 'recent', 'iso_language_code': 'en'}, lang='en', in_reply_to_screen_name=None, retweet_count=5633, coordinates=None, id_str='1093431237912465408', geo=None, truncated=False, favorited=False, in_reply_to_status_id=None, in_reply_to_user_id_str=None, retweeted=False, is_quote_status=False, id=1093431237912465408, contributors=None, favorite_count=0, entities={'user_mentions': [{'screen_name': 'Evra', 'id_str': '723866725', 'indices': [3, 8], 'id': 723866725, 'name': 'Patrice Evra'}, {'screen_name': 'ManUtd', 'id_str': '558797310', 'indices': [30, 37], 'id': 558797310, 'name': 'Manchester United'}], 'hashtags': [{'text': 'BusbyBabes', 'indices': [95, 106]}, {'text': 'FlowersOfManchester', 'indices': [107, 127]}, {'text': 'ManUtd', 'indices': [128, 135]}], 'urls': [], 'symbols': []}, source='Twitter for iPhone', text='RT @Evra: When you are a true @ManUtd fan or player you know what time it is ... never forget. #BusbyBabes #FlowersOfManchester #ManUtd #hi
# ', place=None, source_url='http://twitter.com/download/iphone', in_reply_to_status_id_str=None, user=User(profile_background_image_url_https='https://abs.twimg.com/images/themes/theme14/bg.gif', is_translator=False, _json={'created_at': 'Thu Jan 14 13:30:38 +0000 2010', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/962432524063510531/hrblAgrr_normal.jpg', 'is_translation_enabled': False, 'friends_count': 148, 'is_translator': False, 'protected': False, 'description': 'loans officer, mufc, love cooking', 'profile_sidebar_fill_color': 'EFEFEF', 'following': False, 'lang': 'en', 'profile_link_color': '009999', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif', 'profile_use_background_image': True, 'follow_request_sent': False, 'verified': False, 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/104810339/1518296768', 'time_zone': None, 'name': 'Karl Breeze', 'profile_text_color': '333333', 'contributors_enabled': False, 'geo_enabled': True, 'statuses_count': 192, 'default_profile': False, 'utc_offset': None, 'translator_type': 'none', 'location': 'bolton', 'notifications': False, 'has_extended_profile': True, 'id': 104810339, 'default_profile_image': False, 'favourites_count': 48, 'profile_image_url': 'http://pbs.twimg.com/profile_images/962432524063510531/hrblAgrr_normal.jpg', 'id_str': '104810339', 'entities': {'description': {'urls': []}}, 'profile_background_color': '131516', 'screen_name': 'Br3ezy87', 'listed_count': 0, 'profile_background_tile': True, 'followers_count': 59, 'url': None, 'profile_sidebar_border_color': 'EEEEEE'}, lang='en', profile_background_image_url='http://abs.twimg.com/images/themes/theme14/bg.gif', verified=False, profile_banner_url='https://pbs.twimg.com/profile_banners/104810339/1518296768', profile_use_background_image=True, profile_text_color='333333', default_profile_image=False, geo_enabled=True, statuses_count=192, default_profile=False, utc_offset=None, url=None, protected=False, profile_image_url='http://pbs.twimg.com/profile_images/962432524063510531/hrblAgrr_normal.jpg', profile_background_color='131516', screen_name='Br3ezy87', listed_count=0, profile_sidebar_border_color='EEEEEE', created_at=datetime.datetime(2010, 1, 14, 13, 30, 38), profile_background_tile=True, _api=<tweepy.api.API object at 0x0000020206AF2CC0>, profile_image_url_https='https://pbs.twimg.com/profile_images/962432524063510531/hrblAgrr_normal.jpg', is_translation_enabled=False, friends_count=148, description='loans officer, mufc, love cooking', following=False, profile_link_color='009999', profile_sidebar_fill_color='EFEFEF', follow_request_sent=False, id_str='104810339', has_extended_profile=True, time_zone=None, name='Karl Breeze', contributors_enabled=False, notifications=False, location='bolton', id=104810339, favourites_count=48, entities={'description': {'urls': []}}, translator_type='none', followers_count=59), author=User(profile_background_image_url_https='https://abs.twimg.com/images/themes/theme14/bg.gif', is_translator=False, _json={'created_at': 'Thu Jan 14 13:30:38 +0000 2010', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/962432524063510531/hrblAgrr_normal.jpg', 'is_translation_enabled': False, 'friends_count': 148, 'is_translator': False, 'protected': False, 'description': 'loans officer, mufc, love cooking', 'profile_sidebar_fill_color': 'EFEFEF', 'following': False, 'lang': 'en', 'profile_link_color': '009999', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif', 'profile_use_background_image': True, 'follow_request_sent': False, 'verified': False, 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/104810339/1518296768', 'time_zone': None, 'name': 'Karl Breeze', 'profile_text_color': '333333', 'contri ...

# %%
df_manutd['Orig_text'] = df_manutd['text']
df_manutd.text = df_manutd.text.str.replace(r'\d+', '')
df_manutd.text = df_manutd['text'].str.replace('[{}]'.format(string.punctuation), '')
df_manutd['text'] = df_manutd['text'].apply(lambda x: ' '.join([word for word in x.lower().split() if word not in (stop)]))
df_manutd['text'] = df_manutd['text'].astype(str)

# %%
df_manutd.text = df_manutd.text.str.replace(r'\d+', '')
df_manutd.text = df_manutd.text.str.replace('http\S+|www.\S+', '', case=False)
df_manutd.text = df_manutd.text.str.replace(r'xe', '', case=False)
df_manutd.text = df_manutd.text.str.replace(r'xf', '', case=False)
df_manutd.text = df_manutd.text.str.replace(r'xb', '', case=False)
df_manutd.text = df_manutd.text.str.replace(r'xa', '', case=False)
df_manutd.text = df_manutd.text.str.replace(r'//', '', case=False)
df_manutd.text = df_manutd.text.str.replace(r'\\', '', case=False)
df_manutd.text = df_manutd.text.str.replace(r'mx', '', case=False)
#m = re.sub(r':.*$', ":", str)
df_manutd.text = df_manutd.text.str.replace(r'brt', '', case=False)
df_manutd.text = df_manutd['text'].str.replace('[{}]'.format(string.punctuation), '')

#stop = set(stopwords.words('english'))
df_manutd['text'] = df_manutd['text'].apply(lambda x: ' '.join([word for word in x.lower().split() if word not in (stop)]))

#ttnz = TweetTokenizer()

#f_manutd['tokenized_tweets'] = df_manutd['text'].apply(ttnz.tokenize)

#n_gram = df_manutd['text'].apply(ngrams(nltk.word_tokenize,n))

# %%
df_manutd.head()
# Out:
#              date_time  \
# 0  2018-03-27 10:27:54
# 1  2018-03-27 10:25:33
# 2  2018-03-27 10:24:36
# 3  2018-03-27 10:22:20
# 4  2018-03-27 10:20:06
#
#                                                                                                             text  \
# 0  bhis best years behind mufc manutd mutv manchesterunited
# 1  manutdlatestcom jose mourinho tells ed woodward aaron ramsey better paul pogba ahead summerxcmove mufc manutd
# 2  b watch manutd game liventwo nights iceland mbw scored last minute corporate tickets midweek eurx
# 3  bbe careful flaunting achievements liverpool used thing manutd acted asx
# 4  edwardstratmann piece eric bailly eurofantasygame manutd epl
#
#                                                                                                                                                            Orig_text
# 0  b'His best years are behind him. #mufc #manutd #mutv #ManchesterUnited https://t.co/hPWsGwXBbT'
# 1  b'RT @ManUtdLatestCom: Jose Mourinho tells Ed Woodward Aaron Ramsey is BETTER than Paul Pogba ahead of summer\xc2\xa0move #mufc #ManUtd https://t.co\xe2\x80\xa6'
# 2  b'#39 Watch a @ManUtd game live\nTwo nights before Iceland, MBW scored last minute corporate tickets to a mid-week Eur\xe2\x80\xa6 https://t.co/o53OEUGlgz'
# 3  b'Be careful when flaunting our achievements, Liverpool used to do this very same thing to #manutd. It only acted as\xe2\x80\xa6 https://t.co/6fPXC31SSS'
# 4  b'RT @EdwardStratmann: A piece on Eric Bailly for @EuroFantasyGame: https://t.co/TpBdkkiRwD #ManUtd #EPL'

# %%
ttnz = TweetTokenizer()

df_manutd['tokenized_tweets'] = df_manutd['text'].apply(ttnz.tokenize)

stemmer = SnowballStemmer(language= 'english', ignore_stopwords= True)
df_manutd['tokenized_tweets'] = df_manutd['tokenized_tweets'].apply(lambda x: [stemmer.stem(y) for y in x])

pd.set_option('display.max_colwidth', -1)
df.head(10)

lemmatizer = WordNetLemmatizer()
df_manutd['tokenized_tweets'] = df_manutd['tokenized_tweets'].apply(lambda x: [lemmatizer.lemmatize(y) for y in x])

# %%
txt = df_manutd.text.str.lower().str.replace(r'\|', ' ').str.cat(sep=' ')
top_N = 30
words = nltk.tokenize.word_tokenize(txt)
word_dist = nltk.FreqDist(words)

stopwords = nltk.corpus.stopwords.words('english')
words_except_stop_dist = nltk.FreqDist(w for w in words if w not in stopwords) 

print('All frequencies, including STOPWORDS:')
print('=' * 60)
rslt = pd.DataFrame(word_dist.most_common(top_N),
                    columns=['Word', 'Frequency'])
rslt = pd.DataFrame(words_except_stop_dist.most_common(top_N),
                    columns=['Word', 'Frequency']).set_index('Word').reset_index()

fig, ax = plt.subplots(figsize=(18,8))
ax = sns.barplot(x='Word',y='Frequency',data=rslt,palette=sns.light_palette("navy",reverse=True,n_colors=21))
plt.xticks(rotation=70)
plt.xticks(size=15)
plt.yticks(size=15)
ax.set(ylim=(0,6000))
ax.set(xlim=(None,20))
ax.set_xlabel('Wrods',size=17)
ax.set_ylabel('Frequency',size=17)
# Out:
# All frequencies, including STOPWORDS:
# ============================================================
# Text(0,0.5,'Frequency')

# %%
rslt.head(10)
# Out:
#             Word  Frequency
# 0  manutd         5768
# 1  mufc           3609
# 2  chrissmalling  2220
# 3  facup          1632
# 4  ggmu           1565
# 5  come           1475
# 6  semifinals     1473
# 7  xxddnnmanutd   1410
# 8  united         1406
# 9  x              1247

# %%
from wordcloud import WordCloud, STOPWORDS

def show_wordcloud(data, title = None):
    wordcloud = WordCloud(
        background_color='black',
        stopwords=stop,
        max_words=150,
        max_font_size=60, 
        collocations = False,
        scale=10,
        random_state=42 # chosen at random by flipping a coin; it was heads
    ).generate(str(data))

    fig = plt.figure(1, figsize=(16, 16))
    plt.axis('off')
    if title: 
        fig.suptitle(title, fontsize=20)
        fig.subplots_adjust(top=2.3)

    plt.imshow(wordcloud)
    plt.show()

show_wordcloud(df_manutd['tokenized_tweets'])
#show_wordcloud(Samsung_Reviews_positive['Reviews'])

# %%
df_manutd_text = vec.transform(df_manutd.text)
df_manutd_text_tfidf = tfidf_transformer.fit_transform(df_manutd_text)
df_pred = cls.predict_proba(df_manutd_text_tfidf)
df_pred_bin = cls.predict(df_manutd_text_tfidf)

# %%
df_pred = pd.DataFrame(df_pred)
df_pred_bin = pd.DataFrame(df_pred_bin)
df_pred_bin = df_pred_bin.reset_index()
df_pred.columns = [['prediction_p', 'prediction_n']]
df_pred = df_pred.reset_index()
df_pred_bin['isPos'] = df_pred_bin[1]

# %%
df_pred_bin.head()
# Out:
#    index  0  isPos
# 0  0      0  0
# 1  1      0  0
# 2  2      0  0
# 3  3      0  0
# 4  4      1  1

# %%
df_manutd_merge = df_manutd.reset_index()

# %%
df_pred = df_pred_bin.merge(df_pred, left_index=True, right_index=True)

# %%
df_pred = df_pred.merge(df_manutd_merge)

# %%
df_pred.head()
# Out:
#    index  0  isPos  (index,)  (prediction_p,)  (prediction_n,)  \
# 0  0      0  0      0         0.517010         0.482990
# 1  1      0  0      1         0.557757         0.442243
# 2  2      0  0      2         0.541662         0.458338
# 3  3      0  0      3         0.644088         0.355912
# 4  4      1  1      4         0.444429         0.555571
#
#              date_time  \
# 0  2018-03-27 10:27:54
# 1  2018-03-27 10:25:33
# 2  2018-03-27 10:24:36
# 3  2018-03-27 10:22:20
# 4  2018-03-27 10:20:06
#
#                                                                                                             text  \
# 0  bhis best years behind mufc manutd mutv manchesterunited
# 1  manutdlatestcom jose mourinho tells ed woodward aaron ramsey better paul pogba ahead summerxcmove mufc manutd
# 2  b watch manutd game liventwo nights iceland mbw scored last minute corporate tickets midweek eurx
# 3  bbe careful flaunting achievements liverpool used thing manutd acted asx
# 4  edwardstratmann piece eric bailly eurofantasygame manutd epl
#
#                                                                                                                                                            Orig_text  \
# 0  b'His best years are behind him. #mufc #manutd #mutv #ManchesterUnited https://t.co/hPWsGwXBbT'
# 1  b'RT @ManUtdLatestCom: Jose Mourinho tells Ed Woodward Aaron Ramsey is BETTER than Paul Pogba ahead of summer\xc2\xa0move #mufc #ManUtd https://t.co\xe2\x80\xa6'
# 2  b'#39 Watch a @ManUtd game live\nTwo nights before Iceland, MBW scored last minute corporate tickets to a mid-week Eur\xe2\x80\xa6 https://t.co/o53OEUGlgz'
# 3  b'Be careful when flaunting our achievements, Liverpool used to do this very same thing to #manutd. It only acted as\xe2\x80\xa6 https://t.co/6fPXC31SSS'
# 4  b'RT @EdwardStratmann: A piece on Eric Bailly for @EuroFantasyGame: https://t.co/TpBdkkiRwD #ManUtd #EPL'
#
#                                                                                                               tokenized_tweets
# 0  [bhis, best, year, behind, mufc, manutd, mutv, manchesterunit]
# 1  [manutdlatestcom, jose, mourinho, tell, ed, woodward, aaron, ramsey, better, paul, pogba, ahead, summerxcmov, mufc, manutd]
# 2  [b, watch, manutd, game, liventwo, night, iceland, mbw, score, last, minut, corpor, ticket, midweek, eurx]
# 3  [bbe, care, flaunt, achiev, liverpool, use, thing, manutd, act, asx]
# 4  [edwardstratmann, piec, eric, bailli, eurofantasygam, manutd, epl]

# %%
df_pred.drop(df_pred.columns[[0,1,3]],axis=1,inplace=True)

# %%
df.rename(columns={'oldName1': 'newName1', 'oldName2': 'newName2'}, inplace=True)

# %%
#df_pred = df_pred.join(df_manutd)

# %%
df_pred = df_pred.drop(['text', 'tokenized_tweets'],axis=1)

# %%
df_pred.head()
# Out:
#    isPos  (prediction_p,)  (prediction_n,)            date_time  \
# 0  0      0.517010         0.482990         2018-03-27 10:27:54
# 1  0      0.557757         0.442243         2018-03-27 10:25:33
# 2  0      0.541662         0.458338         2018-03-27 10:24:36
# 3  0      0.644088         0.355912         2018-03-27 10:22:20
# 4  1      0.444429         0.555571         2018-03-27 10:20:06
#
#                                                                                                                                                            Orig_text
# 0  b'His best years are behind him. #mufc #manutd #mutv #ManchesterUnited https://t.co/hPWsGwXBbT'
# 1  b'RT @ManUtdLatestCom: Jose Mourinho tells Ed Woodward Aaron Ramsey is BETTER than Paul Pogba ahead of summer\xc2\xa0move #mufc #ManUtd https://t.co\xe2\x80\xa6'
# 2  b'#39 Watch a @ManUtd game live\nTwo nights before Iceland, MBW scored last minute corporate tickets to a mid-week Eur\xe2\x80\xa6 https://t.co/o53OEUGlgz'
# 3  b'Be careful when flaunting our achievements, Liverpool used to do this very same thing to #manutd. It only acted as\xe2\x80\xa6 https://t.co/6fPXC31SSS'
# 4  b'RT @EdwardStratmann: A piece on Eric Bailly for @EuroFantasyGame: https://t.co/TpBdkkiRwD #ManUtd #EPL'

# %%
df_pred.date_time = pd.to_datetime(df_pred.date_time)
df_pred.date_time = df_pred.date_time.dt.date
df_pred = df_pred.groupby('date_time').mean().reset_index()

# %%
from googlefinance.client import get_price_data, get_prices_data, get_prices_time_data

params = [
    # Dow Jones
    {
        'q': "MANU",
        'x': "NYSE",
    },
]
period = "1M"
interval = 60*60*24 # 30 minutes
# get open, high, low, close, volume time data (return pandas dataframe)
df_stock = get_prices_time_data(params, period, interval)

# %%
df_stock.index.names = ['date_time']
df_stock.reset_index(inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-95-76e0d4f7d2cf> in <module>()
# ----> 1 df_stock.index.names = ['date_time']
#       2 df_stock.reset_index(inplace=True)
#
# NameError: name 'df_stock' is not defined

# %%
df_stock.tail()
# Out:
#              date_time  MANU_Open  MANU_High  MANU_Low  MANU_Close  \
# 15 2018-03-20 21:00:00  20.00      20.425     19.70     19.75
# 16 2018-03-21 21:00:00  19.75      19.750     19.30     19.45
# 17 2018-03-22 21:00:00  19.50      19.550     19.30     19.50
# 18 2018-03-23 21:00:00  19.55      19.600     19.05     19.10
# 19 2018-03-26 22:00:00  19.40      19.400     18.70     18.85
#
#     MANU_Volume
# 15  30313
# 16  34713
# 17  20185
# 18  17259
# 19  29867

# %%
import datetime
date = datetime.date(2018, 3, 15)
df_stock = df_stock[df_stock['date_time'] > date]
df_stock.date_time = pd.to_datetime(df_stock.date_time)
df_stock.date_time = df_stock.date_time.dt.date

# %%
df = df_stock.merge(df_pred)

# %%
df.head()
# Out:
#     date_time  MANU_Open  MANU_High  MANU_Low  MANU_Close  MANU_Volume  \
# 0  2018-03-19  19.75      20.000     19.40     19.85       37596
# 1  2018-03-20  20.00      20.425     19.70     19.75       30313
# 2  2018-03-21  19.75      19.750     19.30     19.45       34713
# 3  2018-03-22  19.50      19.550     19.30     19.50       20185
# 4  2018-03-23  19.55      19.600     19.05     19.10       17259
#
#     index     isPos  prediction_p  prediction_n
# 0  5505.5  0.469734  0.518894      0.481106
# 1  4718.0  0.512684  0.494135      0.505865
# 2  3984.0  0.634214  0.465373      0.534627
# 3  3222.5  0.498756  0.502174      0.497826
# 4  2523.0  0.542857  0.489544      0.510456

# %%
import numpy as np
import matplotlib.pyplot as plt

fig, ax1 = plt.subplots(figsize=(20,10))
t = df['date_time']
s1 = df['MANU_High']
ax1.plot(t, s1, 'b-')
ax1.set_xlabel('Date', size = 15)
# Make the y-axis label, ticks and tick labels match the line color.
ax1.set_ylabel('Stock Price', color='b', size =15)
ax1.tick_params('y', colors='b')

# ax2 = ax1.twinx()
# s2 = df['prediction_p']
# ax2.plot(t, s2, 'r-')
# ax2.set_ylabel('Positve Sentiment', color='r' , size = 15)
# ax2.tick_params('y', colors='r')

ax2 = ax1.twinx()
s2 = df['isPos']
ax2.plot(t, s2, 'g-')
ax2.set_ylabel('Positve Sentiment', color='g' , size = 15)
ax2.tick_params('y', colors='g')

fig.tight_layout()
plt.show()
